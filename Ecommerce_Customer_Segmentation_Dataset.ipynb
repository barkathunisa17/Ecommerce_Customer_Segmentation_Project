# %%
import pandas as pd
import numpy as np

data = {
    "CustomerID": [
        "C001", "C002", "C003", "C004", "C005",
        "C006", "C007", "C008", "C009", "C010",
        "C011", "C012", "C013", "C014", "C015",
        "C016", "C017", "C018", "C019", "C020",
        "C021", "C022", "C023", "C024", "C025",
        "C026", "C027", "C028", "C029", "C030"
    ],

    "InvoiceNo": [
        "INV001", "INV002", "INV003", "INV004", "INV005",
        "INV006", "INV007", "INV008", "INV009", "INV010",
        "INV011", "INV012", "INV013", "INV014", "INV015",
        "INV016", "INV017", "INV018", "INV019", "INV020",
        "INV021", "INV022", "INV023", "INV024", "INV025",
        "INV026", "INV027", "INV028", "INV029", "INV030"
    ],

    "InvoiceDate": [
        "2025-01-05", "2025-01-08", "2025-01-12",
        "2025-01-15", "2025-01-20", "2025-02-02",
        "2025-02-06", "2025-02-10", "2025-02-14",
        "2025-02-18", "2025-03-01", "2025-03-05",
        "2025-03-10", "2025-03-14", "2025-03-20",
        "2025-04-02", "2025-04-07", "2025-04-12",
        "2025-04-18", "2025-04-25", "2025-05-03",
        "2025-05-09", "2025-05-15", "2025-05-21",
        "2025-06-01", "2025-06-08", "2025-06-14",
        "2025-06-20", "2025-06-25", "2025-06-30"
    ],

    "Product": [
        "Laptop", "Headphones", "Mouse", "Keyboard", "Smartphone",
        "Laptop", "Tablet", "Headphones", "Smart Watch", "Mouse",
        "Keyboard", "Laptop", "Smartphone", "Tablet", "Headphones",
        "Mouse", "Laptop", "Smart Watch", "Keyboard", "Smartphone",
        "Tablet", "Headphones", "Laptop", "Mouse", "Smart Watch",
        "Keyboard", "Smartphone", "Tablet", "Headphones", "Laptop"
    ],

    "Quantity": [
        1, 2, 3, 1, 2,
        1, 2, 3, 1, 4,
        2, 1, 2, 1, 3,
        2, 1, 2, 3, 1,
        2, 4, 1, 3, 2,
        1, 2, 3, 2, 1
    ],

    "UnitPrice": [
        50000, 1500, 500, 2000, 30000,
        55000, 25000, 1800, 8000, 600,
        2200, 52000, 32000, 28000, 1600,
        550, 48000, 7500, 2100, 35000,
        26000, 1700, 60000, 650, 8500,
        2300, 33000, 27000, 1900, 58000
    ]
}

df = pd.DataFrame(data)

df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

print(df)
# Out:
#    CustomerID InvoiceNo InvoiceDate      Product  Quantity  UnitPrice  \
# 0        C001    INV001  2025-01-05       Laptop         1      50000
# 1        C002    INV002  2025-01-08   Headphones         2       1500
# 2        C003    INV003  2025-01-12        Mouse         3        500
# 3        C004    INV004  2025-01-15     Keyboard         1       2000
# 4        C005    INV005  2025-01-20   Smartphone         2      30000
# 5        C006    INV006  2025-02-02       Laptop         1      55000
# 6        C007    INV007  2025-02-06       Tablet         2      25000
# 7        C008    INV008  2025-02-10   Headphones         3       1800
# 8        C009    INV009  2025-02-14  Smart Watch         1       8000
# 9        C010    INV010  2025-02-18        Mouse         4        600
# 10       C011    INV011  2025-03-01     Keyboard         2       2200
# 11       C012    INV012  2025-03-05       Laptop         1      52000
# ...
